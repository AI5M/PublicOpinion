# %%
import requests as req
from bs4 import BeautifulSoup as bs

# %%
session_requests = req.session()
result = session_requests.post('https://cloudwinner.gouptech.com.tw/Account/Login',
                  data={'LoginID':'h124538081','Password':'856236alex'})

soup = bs(result.text,'html.parser')

# %%
soup
# Out:
# <!DOCTYPE HTML>
#
# <html dir="ltr" lang="zh-tw" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta charset="utf-8"/>
# <title>Error</title>
# <meta name="description"/>
# <meta content="no-cache" http-equiv="cache-control"/>
# <meta content="max-age=0" http-equiv="cache-control"/>
# <meta content="0" http-equiv="expires"/>
# <meta content="Tue, 01 Jan 1980 1:00:00 GMT" http-equiv="expires"/>
# <meta content="no-chche" http-equiv="prama"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0" name="viewport"/>
# <!-- For Facebook -->
# <meta content="https://cloudwinner.gouptech.com.tw/Error/Error?500;https://cloudwinner.gouptech.com.tw:443/Account/Login&amp;r=636622258559551058" property="og:url">
# <meta content="保險贏家社群服務平台" property="og:site_name"/>
# <meta property="og:title"/>
# <meta property="og:description"/>
# ...

# %%
result = req.get('https://cloudwinner.gouptech.com.tw/Proposal/InsuranceInfo?iCmpyNo=CH&iMark=01&iDispClass=D')
soup = bs(result.text,'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html style="background-color: #FFFFFF;font-size: 12px;">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no" name="viewport"/>
# <title>登錄</title>
# <link href="http://cloudwinner.gouptech.com.tw/Home/CloudIcon?xx=cfb0099c-e222-44b8-9b6a-2e238ff692b8" id="favicon" rel="shortcut icon" type="image/x-icon"/>
# <link href="/Content/css_2015RWD?v=gTmm2MR5gst7qkDmssGurBjSQI4GZlwYQGOT2G3f3Ds1" rel="stylesheet"/>
# <script src="/Content/js_2015RWD?v=xtPZ9ko5ImubtrzhC0x3giu7vRG6Yy-w_E6yW6YTf741"></script>
# </head>
# <body leftmargin="0" style="background-color: #FFFFFF;" topmargin="0">
# <link href="/Content/validationEngine.jquery.css" rel="Stylesheet" type="text/css"/>
# <script src="/Scripts/dist/js/bootstrap-show-password.min.js"></script>
# <script src="/bundles/PlaceHolder?v=tAHlqVvo3pCaKTGT_I-fp0rf9TuVJmcnlFlN2Qhx3-g1"></script>
# ...
